# %% [markdown]
# <!-- Google Fonts -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 20px;
#     background: linear-gradient(125deg, #d73027 7%, #fdae61 47%, #a6d96a 85%, #1a9850 100%);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         🏢 IBM HR Analytics Employee Attrition
#     </h1>
# </div>

# %% [markdown]
# ### 📂 Dataset Overview
#
# Attrition in a company is the situation where employees leave their jobs for voluntary or involuntary reasons, which can be due to retirement, resignation or termination of contract, or when a company decides to make a position redundant. Attrition affects the performance of teams, the quality of output, and increases recruitment and training costs. In this project, the group will focus on finding out what causes attrition in the company.
#
# In this project, I analyze the IBM HR Analytics Employee Attrition & Performance dataset to explore factors associated with employee turnover. Through exploratory data analysis and machine learning algorithms, I build predictive models to identify employees likely to leave, helping organizations take proactive measures to improve retention.
#
# ### 🧾 Key Features
#
# **1. Age:** Age of the employee in numeric.<br>
# **2. Attrition:** Attrition of employee categorical : Yes/ No.<br>
# **3. BusinessTravel:** It is a categorical column about employee business travel : Travel Frequently/ Rarely Travel/ Non- Travel.<br>
# **4. DailyRate:** It is a numerical column signify daily working rate of employee.<br>
# **5. Department:** It is a categorical column signify employee"s working department.<br>
# **6. DistanceFromHome:** It is a numerical column signify total distance of employee"s home from office.<br>
# **7. Education:** It is a categorical column signify level of employee"s education : (1 "Below College", 2 "College", 3 "Bachelor", 4 "Master", 5 "Doctor")<br>
# **8. EducationField:** It is a categorical column signify education field of employees.<br>
# **9. EmployeeCount:** Number of employees in numerical. It has only one unique value i.e., 1<br>
# **10. EmployeeNumber:** It is a unique numerical Id assigned to every employee.<br>
# **11. EnvironmentSatisfaction:** It is a categorical column having following values : (1 "Low", 2 "Medium", 3 "High", 4 "Very High")<br>
# **12. Gender:** It is a categorical column having only 2 values Male and female.<br>
# **13. HourlyRate:** It is a numerical column signify hourly working rate of employee.<br>
# **14. JobInvolvement:** It is a categorical column having following values : (1 "Low", 2 "Medium", 3 "High", 4 "Very High")<br>
# **15. JobLevel:** It is a categorical column signify level of job i.e., 1,2,3,4 and 5<br>
# **16. JobRole:** It is a categorical column signifying role of employee i.e., sales executive, research scientists etc.<br>
# **17. JobSatisfaction:** It signifies how satisfied an employee is with the job : (1 "Low", 2 "Medium", 3 "High", 4 "Very High")<br>
# **18. MaritalStatus:** It is a categorical column signifies marital status of employee i.e., Married, Single, Divorced etc.<br>
# **19. MonthlyIncome:** It is a numerical column signify monthly income of the employee.<br>
# **20. MonthlyRate:** It is a numerical column signify monthly rate of working by employee.<br>
# **21. NumCompaniesWorked:** It is a numerical column signify number of companies an employee previously worked for.<br>
# **22. Over18:** It is a boolean field signify whether employee age is over 18 or not.<br>
# **23. OverTime:** It is a boolean field signify whether employee work overtime or not.<br>
# **24. PercentSalaryHike:** It is a numerical column signify percentage of hike received recently by an employee.<br>
# **25. PerformanceRating:** It is a categorical column signify performance rating of employee (1 "Low", 2 "Good",
# 3 "Excellent", 4 "Outstanding")<br>
# **26. RelationshipSatisfaction:** It is a categorical column signify relationship bonding status with co workers
# (1 "Low",2 "Medium",3 "High",4 "Very High")<br>
# **27. StandardHours:** It is a numerical column signify standard working hours of employees.<br>
# **28. StockOptionLevel:** It is a categorical column. It has four categories 0, 1, 2 and 3 <br>
# **29. TotalWorkingYears:** It is a numerical column signify total working years of employees. <br>
# **30. TrainingTimesLastYear:** It is a numerical column signify total number of times employee got training. <br>
# **31. WorkLifeBalance:** It is a categorical column signify work life balance (1 "Bad",2 "Good",3 "Better",4 "Best")<br>
# **32. YearsAtCompany:** It is a numerical column signify total number of years spent by employee in current company.<br>
# **33. YearsInCurrentRole:** It is a numerical column signify total number of years spent by employee in current job role in current company.<br>
# **34. YearsSinceLastPromotion:** It is a numerical column signify total number of years since last promotion of employee in current company.<br>
# **35. YearsWithCurrManager:** It is a numerical column signify total number of years employee work under current manager in current company.<br>
#
# ### 📁 Files Provided
#
# * `WA_Fn-UseC_-HR-Employee-Attrition.csv` (1000 samples): Contains all features (sources: [Kaggle Dataset](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset))
#
# ### 🎯 Project Objective
#
# The primary objective of this notebook is to **build machine learning model to predict and EDA**.
#
# Key components of the approach include:
#
# * **🔍 Exploratory Data Analysis (EDA):** Understand feature distributions, relationships.
# * **⚙️ Feature Engineering:** Encode categorical variables and align schema across training and test data.
# * **📈 Modeling:** Train an ensemble model with hyperparameters tuned.
# * **🔢 Multi-Label Prediction Strategy:** Generate predictions for each test row.
# * **🧪 Evaluation Framework:**
#
#   * Cross-validation.
#   * Metrics: **Accuracy** and **ROC-AUC**.

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Import Libraries
#     </h1>
# </div>

# %%
# Core data manipulation libraries
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical functions
from scipy.stats import skew

# Display utilities for Jupyter notebooks
from IPython.display import display

# Machine learning preprocessing and modeling
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Statistical
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, probplot
from scipy.stats import mannwhitneyu
from scipy.stats import levene
from scipy.stats import ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from scipy.stats import kruskal

# Suppress warnings for cleaner output
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500) # To display all the columns of dataframe
pd.set_option('max_colwidth', None) # To set the width of the column to maximum
sns.set_theme()

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Load Data</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Load Data
#     </h1>
# </div>

# %%
# Load the datasets
df_HR_Attrition = pd.read_csv("D:/02_DATA/02_MINDX/00_MODULE_1/FINAL_PROJECT/02_PYTHON/WA_Fn-UseC_-HR-Employee-Attrition.csv")
# Verify shapes
print("Data Shape:", df_HR_Attrition.shape)
# Out:
# Data Shape: (1470, 35)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Data Preview and Info
#     </h1>
# </div>

# %%
# Display few rows of each dataset
df_HR_Attrition.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# As per the information "Key Feature" we will convert categorical numerically encoded columns into their categories
# WorkLifeBalance
choices_workLifeBalance = ["Bad", "Good", "Better", "Best"]
conditions = [
    (df_HR_Attrition["WorkLifeBalance"] == 1),
    (df_HR_Attrition["WorkLifeBalance"] == 2),
    (df_HR_Attrition["WorkLifeBalance"] == 3),
    (df_HR_Attrition["WorkLifeBalance"] == 4)
]
df_HR_Attrition["WorkLifeBalance"] = np.select(conditions, choices_workLifeBalance, default="Unknown")

# Education
choices_education = ["Below College", "College", "Bachelor", "Master", "Doctor"]
conditions = [
    (df_HR_Attrition["Education"] == 1),
    (df_HR_Attrition["Education"] == 2),
    (df_HR_Attrition["Education"] == 3),
    (df_HR_Attrition["Education"] == 4),
    (df_HR_Attrition["Education"] == 5)
]
df_HR_Attrition["Education"] = np.select(conditions, choices_education, default="Unknown")

# Environment Satisfaction
choices = ["Low", "Medium", "High", "Very High"]
conditions = [
    (df_HR_Attrition["EnvironmentSatisfaction"] == 1),
    (df_HR_Attrition["EnvironmentSatisfaction"] == 2),
    (df_HR_Attrition["EnvironmentSatisfaction"] == 3),
    (df_HR_Attrition["EnvironmentSatisfaction"] == 4)
]
df_HR_Attrition["EnvironmentSatisfaction"] = np.select(conditions, choices, default="Unknown")

# JobInvolvement
conditions = [
    (df_HR_Attrition["JobInvolvement"] == 1),
    (df_HR_Attrition["JobInvolvement"] == 2),
    (df_HR_Attrition["JobInvolvement"] == 3),
    (df_HR_Attrition["JobInvolvement"] == 4)
]
df_HR_Attrition["JobInvolvement"] = np.select(conditions, choices, default="Unknown")

# JobSatisfaction
conditions = [
    (df_HR_Attrition["JobSatisfaction"] == 1),
    (df_HR_Attrition["JobSatisfaction"] == 2),
    (df_HR_Attrition["JobSatisfaction"] == 3),
    (df_HR_Attrition["JobSatisfaction"] == 4)
]
df_HR_Attrition["JobSatisfaction"] = np.select(conditions, choices, default="Unknown")

# RelationshipSatisfaction
conditions = [
    (df_HR_Attrition["RelationshipSatisfaction"] == 1),
    (df_HR_Attrition["RelationshipSatisfaction"] == 2),
    (df_HR_Attrition["RelationshipSatisfaction"] == 3),
    (df_HR_Attrition["RelationshipSatisfaction"] == 4)
]
df_HR_Attrition["RelationshipSatisfaction"] = np.select(conditions, choices, default="Unknown")

# PerformanceRating
choices_performanceRating = ["Low", "Good", "Excellent", "Outstanding"]
conditions = [
    (df_HR_Attrition["PerformanceRating"] == 1),
    (df_HR_Attrition["PerformanceRating"] == 2),
    (df_HR_Attrition["PerformanceRating"] == 3),
    (df_HR_Attrition["PerformanceRating"] == 4)
]
df_HR_Attrition["PerformanceRating"] = np.select(conditions, choices_performanceRating, default="Unknown")

# StockOptionLevel
choices_stockOptionLevel = ["Basic", "Standard", "Advanced", "Elite"]
conditions = [
    (df_HR_Attrition["StockOptionLevel"] == 0),
    (df_HR_Attrition["StockOptionLevel"] == 1),
    (df_HR_Attrition["StockOptionLevel"] == 2),
    (df_HR_Attrition["StockOptionLevel"] == 3)
]
df_HR_Attrition["StockOptionLevel"] = np.select(conditions, choices_stockOptionLevel, default="Unknown")

# Attrition
choices_attrition = [0, 1]
conditions = [
    (df_HR_Attrition["Attrition"] == "No"),
    (df_HR_Attrition["Attrition"] == "Yes")
]
df_HR_Attrition["Attrition"] = np.select(conditions, choices_attrition, default=-1)

# %%
df_HR_Attrition.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 4                 2  Below College        Medical              1
#
#    EmployeeNumber EnvironmentSatisfaction  Gender  HourlyRate JobInvolvement  \
# ...

# %%
# We need to update the data for the columns, this helps to reduce memory.
df_HR_Attrition = df_HR_Attrition.astype({
    "Age": "int8",
    "Attrition": "int8",
    "DailyRate": "int16",
    "EmployeeCount": "int8",
    "EmployeeNumber": "int16",
    "HourlyRate": "int8",
    "MonthlyIncome": "int16",
    "MonthlyRate": "int16",
    "NumCompaniesWorked": "int8",
    "PercentSalaryHike": "int8",
    "StandardHours": "int8",
    "TotalWorkingYears": "int8",
    "TrainingTimesLastYear": "int8",
    "YearsAtCompany": "int8",
    "YearsInCurrentRole": "int8",
    "YearsSinceLastPromotion": "int8",
    "YearsWithCurrManager": "int8"
})

# %% [markdown]
# 🔴 There are three columns (`EmployeeCount`, `Over18` and `StandardHours`) which have only 1 unique value which will be of no use in prediction process. <br>
# 🔴 The `EmployeeNumber` column is typically a unique identifier used to distinguish employees in a dataset. However, in the context of data analysis or predictive modeling, this column does not provide useful information so we need to drop this column.

# %%
# Drop columns "StandardHours", "EmployeeCount", "Over18" and "EmployeeNumber"
df_HR_Attrition.drop(columns=["StandardHours", "EmployeeCount", "Over18", "EmployeeNumber"], inplace=True)

# %%
cat_features = ["BusinessTravel", "Department", "Education", "EducationField", "EnvironmentSatisfaction", "Gender", "JobInvolvement",
            "JobLevel", "JobRole", "JobSatisfaction", "MaritalStatus", "OverTime", "PerformanceRating", "RelationshipSatisfaction",
            "StockOptionLevel", "WorkLifeBalance"]
def convert_cat(features, df = df_HR_Attrition):
    for feature in features:
        if feature in df.columns:
            df[feature] = df[feature].astype("category")
        else:
            pass

convert_cat(cat_features)

# %%
# Display information about the DataFrames
df_HR_Attrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int8
#  1   Attrition                 1470 non-null   int8
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int16
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   category
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   category
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int8
#  11  JobInvolvement            1470 non-null   category
#  12  JobLevel                  1470 non-null   category
# ...

# %% [markdown]
# **Insights from Initial Data Exploration**
#
# **Dataset Size and Structure**
#    - The **dataset** contains `1479` samples with `31` columns, including the target feature `Attrition`.
#
# **Feature Overview**
#    - **Numerical features:** `Age`,  `DailyRate`,  `DistanceFromHome`,  `HourlyRate`,  `MonthlyIncome`,  `MonthlyRate`,  `NumCompaniesWorked`,  `PercentSalaryHike`,  `TotalWorkingYears`,  `TrainingTimesLastYear`,  `YearsAtCompany`,  `YearsInCurrentRole`,  `YearsSinceLastPromotion`,  `YearsWithCurrManager`.
#    - **Categorical features:** `BusinessTravel`, `Department`, `Education`, `EducationField`, `EnvironmentSatisfaction`, `Gender`, `JobInvolvement`, `JobLevel`, `JobRole`, `JobSatisfaction`, `MaritalStatus`, `OverTime`, `PerformanceRating`, `RelationshipSatisfaction`, `StockOptionLevel`, `WorkLifeBalance`.
#
# **Data Completeness**
#    - The datasets have **no missing values**, which simplifies preprocessing and modeling.
#    - Data types are appropriate: numerical features are integer, and categorical features are category.

# %%
print("Data describe:")
cm = sns.light_palette("blue", as_cmap=True)
display(df_HR_Attrition.drop(columns="Attrition", axis=1).describe().T.style.background_gradient(cmap=cm))
# Out:
# Data describe:
# <style type="text/css">
# ...

# %% [markdown]
# ## Descriptive Insights from Dataset Statistics
#
# We examined the summary statistics of the numerical features across the datasets. The statistics include count, mean, standard deviation, minimum, quartiles, and maximum values.
#
# **Age**
#
# - The age range from `18` to `60`, with a mean as `36.92` (slightly larger than median ⇒ the distribution is roughly symmetric, with no strong skewness) and a standard deviation of approximately `9.13`.
# - The IRQ between `30` (25th percentile) and `43` (75th percentile), suggesting that 50% of employees are between 30 and 43 years old.
#
# **DailyRate**
#
# - The value in range from `102` to `1499`, with a mean around `802.5` (the mean ≈ median, indicating a very symmetric distribution) and a standard deviation is `403.5`.
# - The IRQ between `465` (25th percentile) and `1157` (75th percentile), suggesting that 50% of employees have daily rates in this middle range.
#
# **DistanceFromHome**
#
# - The values range from 1 to 29 kilometers, with a mean of ~9.2 km and a standard deviation of ~8.1, suggesting a wide spread in commuting distance.
# - The interquartile range (IQR) lies between 2 (25th percentile) and 14 (75th percentile), meaning 50% of employees live within 2 to 14 km from the workplace.
# - The distribution is right-skewed, indicating a majority live close to work, but a smaller portion commutes much further (e.g., 25+ km).
#
# **HourlyRate**
#
# - The HourlyRate ranges from 30 to 100. The mean is approximately 65.89, and the median is 66.0, indicating a roughly symmetric distribution (since mean ≈ median).
# - The standard deviation is around 20.33, meaning most employees earn between 45.56 and 86.22 per hour.
# - The Interquartile Range (IQR) is from 48 (25th percentile) to 83 (75th percentile), showing that 50% of employees have an hourly rate between 48 and 83.
# - No strong skewness is observed — the distribution is relatively balanced
#
# **MonthlyRate**
#
# - Values span from 2094 to 26999, with a mean of 14313.10 and a median of 14235.5. The mean ≈ median, indicating a fairly symmetric distribution.
# - Standard deviation: 7117.79 – shows wide variability. IQR: 8047 to 20461.5 ⇒ Half of the employees fall in this wide middle range.
#
# **NumCompaniesWorked**
#
# - The number of companies an employee has worked for ranges from 0 to 9. The mean is approximately 2.69, and the median is 2.0, indicating a slightly right-skewed distribution.
# - The standard deviation is about 2.5, meaning most employees have worked for between 0.2 and 5.2 companies. The IQR is between 1 (25th percentile) and 4 (75th percentile), meaning 50% of employees have worked for 1 to 4 companies.
# - A few employees have worked for more than 6 companies, which may be considered **outliers**, but can be reasonable for experienced professionals or frequent job changers.
#
# **PercentSalaryHike**
#
# - The salary hike percentage ranges from 11% to 25%. The mean is approximately 15.21%, and the median is 14%, showing a slight right skew.
# - The standard deviation is about 3.66, so most employees received a raise within the range of approximately 11.55% to 18.87%. The interquartile range (IQR) is between 12% (Q1) and 18% (Q3), indicating that 50% of employees received a raise in this range.
# - A small number of employees received very high hikes (≥ 22–25%), which could indicate top performers, new roles, or adjustments due to market salary alignment.
#
# **TotalWorkingYears**
#
# - The range of total working years spans from 0 to 40 years. The mean is approximately 11.28, while the median is 10, indicating a slight right-skew.
# - The standard deviation is 7.78, suggesting that most employees have between 3.5 to 19 years of experience.
# The interquartile range (IQR) lies between 6 (Q1) and 15 (Q3). This means that 50% of employees have between 6 and 15 total years of work experience.
#
# **TrainingTimesLastYear**
#
# - Values range from 0 to 6, indicating that each employee could attend up to 6 training sessions per year. Mean ≈ 2.80, Median = 3, suggesting a roughly symmetric distribution, with a slight left skew.
# - Standard deviation ≈ 1.29, meaning most employees attended between 1.5 and 4 training sessions during the year. IQR spans from 2 (Q1) to 4 (Q3) ⇒ 50% of employees participated in 2 to 4 training sessions annually.
# - A small portion of employees had no training sessions during the year (0), while a few attended up to 6 sessions. This could reflect:
#     - Different training needs across departments or job roles.
#     - New hires or low-performing employees might receive more frequent training.
#     - Some employees may be too busy or lacked access to training opportunities.
#
# **YearsAtCompany**
#
# - Range: from 0 to 40 years, showing a wide variety of company tenures among employees. Mean ≈ 7.01, Median = 5, indicating a right-skewed distribution — a larger portion of employees are relatively new, while a few have stayed for decades.
# - Standard deviation ≈ 6.13, suggesting high variability in tenure. IQR (Interquartile Range) is from 2 (Q1) to 9 (Q3) ⇒ 50% of employees have worked between 2 to 9 years.
#
# **YearsInCurrentRole**
#
# - Range: from 0 to 18 years, indicating varying levels of experience in current positions.Mean ≈ 4.23, Median = 3, showing a right-skewed distribution — most employees have relatively short tenure in their current role.
# - Standard Deviation ≈ 3.62, suggesting moderate variability. IQR (Interquartile Range): from 2 (Q1) to 7 (Q3) ⇒ 50% of employees have been in their role for 2 to 7 years.
#
# **YearsSinceLastPromotion**
# - Range: from 0 to 15 years, reflecting a broad spectrum of promotion recency. Mean ≈ 2.19, Median = 1 → indicates a right-skewed distribution.
# - A large portion of employees haven't been promoted recently:
#     - 0 years → likely recently promoted.
#     - The majority of employees were promoted within the last 1–2 years.
# - Standard Deviation ≈ 3.22, showing variability in promotion timelines. IQR: from 0 (Q1) to 3 (Q3) ⇒ 50% of employees were promoted 0 to 3 years ago.
#
# **YearsWithCurrManager**
# - Range: from 0 to 17 years, indicating diverse levels of managerial continuity. Mean ≈ 4.12, Median = 3 ⇒ shows a right-skewed distribution.
# - Standard Deviation ≈ 3.57, suggesting moderate variation in the length of managerial relationships. Interquartile Range (IQR): from 2 (Q1) to 7 (Q3) ⇒ 50% of employees have been with their current manager between 2 and 7 years.

# %%
df_HR_Attrition.describe(include=["category", "object"]).T
# Out:
#                          count unique                     top  freq
# BusinessTravel            1470      3           Travel_Rarely  1043
# Department                1470      3  Research & Development   961
# Education                 1470      5                Bachelor   572
# EducationField            1470      6           Life Sciences   606
# EnvironmentSatisfaction   1470      4                    High   453
# Gender                    1470      2                    Male   882
# JobInvolvement            1470      4                    High   868
# JobLevel                  1470      5                       1   543
# JobRole                   1470      9         Sales Executive   326
# JobSatisfaction           1470      4               Very High   459
# MaritalStatus             1470      3                 Married   673
# OverTime                  1470      2                      No  1054
# PerformanceRating         1470      2               Excellent  1244
# ...

# %% [markdown]
# ## Categorical Feature Insights (Overview)
#
# - Some features such as BusinessTravel, Department, and OverTime have uneven distributions, with one value dominating. This may affect analysis and modeling.
# - Most employees are male, married, work in R&D, and have a Bachelor's degree.
# - Most employees do not work overtime and rate their work-life balance as good.
# - Features such as BusinessTravel, OverTime, and WorkLifeBalance may be important factors affecting turnover (Attrition).

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Quality Checks</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Data Quality Checks
#     </h1>
# </div>

# %% [markdown]
# ## Handling Missing Value

# %%
def missing_values_report(df = df_HR_Attrition):
    missing_count = df.isnull().sum().sum()
    rows = len(df)
    
    print("=" * 80)
    print(f" Missing Value Analysis")
    print("=" * 80)
    
    if missing_count == 0:
        print(f"✅ No missing values detected in {rows:,} rows")
    else:
        print(f"⚠️  {missing_count} missing values found in {rows:,} rows")
missing_values_report()
# Out:
# ...
#  Missing Value Analysis
# ...
# ✅ No missing values detected in 1,470 rows

# %% [markdown]
# ## Checking Duplicate Value

# %%
def check_duplicates_report(df=df_HR_Attrition):
    duplicates_count = df.duplicated().sum()
    total_rows = len(df)
    
    print("=" * 80)
    print(f"🔍 Duplicate Analysis")
    print("=" * 80)
    
    if duplicates_count == 0:
        print(f"✅ No duplicates found in {total_rows:,} rows")
    else:
        print(f"⚠️  {duplicates_count} duplicates found ({duplicates_count/total_rows:.2%})")
        print(f"    Total rows affected: {duplicates_count:,}/{total_rows:,}")

check_duplicates_report()
# Out:
# ...
# 🔍 Duplicate Analysis
# ...
# ✅ No duplicates found in 1,470 rows

# %% [markdown]
# ## Checking Outlier Value
#
# * Outliers are data points that significantly differ from other observations. Detecting and handling them is important because they can distort analysis and lead to incorrect conclusions. <br>
# * Using the Interquartile Range (IQR) Method : The IQR method identifies outliers as values `below Q1 - 1.5 * IQR` or `above Q3 + 1.5 * IQR`. <br>
# * If the outlier count is 0, that column has no outliers. <br>
# * If the outlier count is greater than 0, that column contains outliers.

# %%
def checking_outlier(list_feature, df = df_HR_Attrition):
    outlier_info = []
    for feature in list_feature:
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)][feature]
        if len(outliers) == 0:
            outlier_detail = ""
        else:
            outlier_detail = outliers.tolist()
            outlier_info.append({
            "Feature": feature,
            "Outlier Count": len(outliers),
            "Outlier Detail": outlier_detail})
    return pd.DataFrame(outlier_info)

# Source: https://www.geeksforgeeks.org/data-science/detect-and-remove-the-outliers-using-python/
def remove_outlier(list_feature, df = df_HR_Attrition):
    for feature in list_feature:
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        df = df[(df[feature] >= lower_bound) & (df[feature] <= upper_bound)]
    return df

# %%
num_feature = ["Age",  "DailyRate",  "DistanceFromHome",  "HourlyRate",  "MonthlyIncome",  "MonthlyRate",  "NumCompaniesWorked",  "PercentSalaryHike",  "TotalWorkingYears",  "TrainingTimesLastYear",  "YearsAtCompany",  "YearsInCurrentRole",  "YearsSinceLastPromotion",  "YearsWithCurrManager"]
checking_outlier(list_feature=num_feature)
# Out:
#                    Feature  Outlier Count  \
# 0            MonthlyIncome            114
# 1       NumCompaniesWorked             52
# 2        TotalWorkingYears             63
# 3    TrainingTimesLastYear            238
# 4           YearsAtCompany            104
# 5       YearsInCurrentRole             21
# 6  YearsSinceLastPromotion            107
# 7     YearsWithCurrManager             14
#
# ...

# %% [markdown]
# | **Feature**               | **Outlier Observation**    | **Should Remove?** | **Reason for Keeping**                                                               |
# | ------------------------- | -------------------------- | ------------------ | ------------------------------------------------------------------------------------ |
# | `MonthlyIncome`           | 114 high values (> 19,000) | ❌ Do not remove    | High income may reflect senior positions or high-performing departments.             |
# | `NumCompaniesWorked`      | 52 values (7–9 companies)  | ❌ Do not remove    | Reflects job mobility — common in the market.                                        |
# | `TotalWorkingYears`       | 63 values (30–40 years)    | ❌ Do not remove    | Likely senior staff with long careers.                                               |
# | `TrainingTimesLastYear`   | 238 values (5–6 times)     | ❌ Do not remove    | May indicate development-focused employees or roles with high upskilling demands.    |
# | `YearsAtCompany`          | 104 values (25+ years)     | ❌ Do not remove    | Long tenure could reflect loyalty or legacy employees.                               |
# | `YearsInCurrentRole`      | 21 values (15+ years)      | ❌ Do not remove    | Staying long in one role may indicate stagnation or specialization.                  |
# | `YearsSinceLastPromotion` | 107 values (8–15 years)    | ❌ Do not remove    | Could signal overlooked employees — key to attrition modeling.                       |
# | `YearsWithCurrManager`    | 14 values (15–17 years)    | ❌ Do not remove    | Long relationships with managers might influence performance or satisfaction.        |

# %% [markdown]
# ## Data Quality Insights: Missing Values, Duplicates and Outliers.
#
# **Missing Values Analysis**
#
# - **No missing values** were detected in the datasets
#
# **Duplicate Records Analysis**
#
# - We examined the datasets for duplicate rows that could bias the model or inflate performance metrics.
# - **No duplicate records** were found in dataset, confirming the uniqueness and integrity of 0 duplicates out of `1470` rows.
# - The absence of duplicates ensures that the model will not be trained or evaluated on repeated data points, which helps maintain the reliability of results.
#
# **Outliers Records Analysis**
# - We also examined the datasets for checking outliers.
# - **The outliers** were found in dataset at features: `MonthlyIncome`, `NumCompaniesWorked`, `TotalWorkingYears`, `TrainingTimesLastYear`, `YearsAtCompany`, `YearsInCurrentRole`, `YearsSinceLastPromotion`, `YearsWithCurrManager`. But we can not remove them since these outliers reflect reality.

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Exploratory Data Analysis (EDA)</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Exploratory Data Analysis (EDA)
#     </h1>
# </div>

# %% [markdown]
# ## Statistical
#
# ✅ Are the Assumptions of T-Test and ANOVA the Same?
# Yes — T-Test and ANOVA share very similar assumptions, as both are parametric tests used to compare group means. However, there are slight differences due to their intended use.
#
# ✅ Common Assumptions for Both T-Test and ANOVA
#
# | **Assumption**                 | **T-Test**                                        | **ANOVA**                             |
# | ------------------------------ | ------------------------------------------------- | ------------------------------------- |
# | **1. Dependent variable**      | Continuous                                        | Continuous                            |
# | **2. Grouping variable**       | Categorical with **2 groups**                     | Categorical with **3 or more groups** |
# | **3. Normality**               | Data in each group should be normally distributed | Same as T-Test                        |
# | **4. Homogeneity of variance** | Equal variances across groups (`equal_var=True`)  | Same as T-Test                        |
# | **5. Independence**            | Observations must be independent                  | Same as T-Test                        |
#
# 🔄 Key Differences Between T-Test and ANOVA
# | **Criterion**           | **T-Test**                   | **ANOVA**                                       |
# | ----------------------- | ---------------------------- | ----------------------------------------------- |
# | Number of groups        | Compares **2 groups**        | Compares **3 or more groups**                   |
# | Post-hoc tests required | Not required                 | Required if significant (e.g., **Tukey’s HSD**) |
# | Types of tests          | Independent or Paired T-Test | One-Way or Repeated Measures ANOVA              |
#
# 📌 Alternatives When Assumptions Are Violated
# | **Violation**           | **T-Test Alternative**  | **ANOVA Alternative**   |
# | ----------------------- | ----------------------- | ----------------------- |
# | Non-normal distribution | **Mann–Whitney U Test** | **Kruskal–Wallis Test** |
# | Unequal variances       | **Welch’s T-Test**      | **Welch’s ANOVA**       |

# %%
def cal_ChiSquare(cat_feature, target_feature, df, show_expected = False, show_residuals = False):
    """
    Performs Chi-Square test of independence and visualizes the relationship between two categorical variables. <br>
    https://www.scribbr.com/statistics/chi-square-test-of-independence
    Parameters:
        cat_feature (str): Name of the categorical feature.
        target_feature (str): Name of the target categorical feature.
        df (pd.DataFrame): Input dataset.
        show_expected (bool): Whether to print expected frequencies. Default is False.
        show_residuals (bool): Whether to calculate and plot standardized residuals. Default is False.

    Returns:
        None - Prints test statistics, expected frequencies, and plots visualizations.
    """
    print(f"\n🔍 Chi-Square Test of Independence: '{cat_feature}' vs. '{target_feature}'")

    # Contingency table
    crosstab = pd.crosstab(df[cat_feature], df[target_feature])
    chi2, p, dof, expected = chi2_contingency(crosstab)

    print(f"Chi-squared statistic: {chi2:.3f}")
    print(f"Degrees of freedom: {dof}")
    print(f"p-value: {p:.6f}")

    if p < 0.05:
        print("🟢 Significant relationship found between variables (reject H₀).")
    else:
        print("⚪ No significant relationship found (fail to reject H₀).")

    # Optional: show expected frequencies
    if show_expected:
        print("\n📊 Expected Frequencies:")
        print(pd.DataFrame(expected, index=crosstab.index, columns=crosstab.columns))
    else:
        pass

    # Optional: show standardized residuals
    if show_residuals:
        residuals = (crosstab - expected) / np.sqrt(expected)
        print("\n📈 Standardized Residuals:")
        print(round(residuals, 2))

        # Heatmap of residuals
        plt.figure(figsize=(8, 6))
        sns.heatmap(residuals, annot=True, cmap="coolwarm", center=0, fmt=".2f", linewidths=0.5)
        plt.title(f"Standardized Residuals Heatmap: {cat_feature} vs {target_feature}")
        plt.ylabel(cat_feature)
        plt.xlabel(target_feature)
        plt.tight_layout()
        plt.show()
    else:
        pass

def cal_shapiro(cat_feature, num_feature, df, plot_result = False):
    """
    Performs Shapiro-Wilk test to check for normal distribution of a numeric feature across groups. <br>
    https://www.statskingdom.com/shapiro-wilk-test-calculator.html
    Parameters:
        cat_feature (str): Name of the categorical feature.
        num_feature (str): Name of the numeric feature to test.
        df (pd.DataFrame): Input dataset.
        plot_result (bool): Show plot. Default is False.

    Returns:
        None - Prints test results and plots a histogram.
    """
    print(f"🔎 Shapiro-Wilk Normality Test for {num_feature} across {cat_feature} groups")

    for group in df[cat_feature].dropna().unique():
        data = df[df[cat_feature] == group][num_feature].dropna()
        n = len(data)

        if n < 3:
            print(f"⚠️ Group {group} has too few values ({n}) to perform Shapiro-Wilk test.")
        elif n > 5000:
            print(f"⚠️ Group {group} has {n} samples. Shapiro-Wilk may not be reliable for n > 5000.")
        else:
            stat, p = shapiro(data)
            print(f"*"*80)
            print(f"  Shapiro-Wilk statistic: {stat:.3f}")
            print(f"  p-value: {p:.6f}")
            if p > 0.05:
                print(f"  🟢 Group {group} appears to follow a normal distribution.\n")
            else:
                print(f"  ⚪ Group {group} does not appear to follow a normal distribution.\n")

            if plot_result:
                probplot(data, dist="norm", plot=plt)
                plt.title(f"QQ Plot - {group}")
                plt.show()
            else:
                pass

def cal_levene(dataframe, categorical_feature, num_feature, center="mean"):
    """
    Performs Levene’s test to assess the equality of variances across groups. <br>
    https://www.geeksforgeeks.org/levenes-test
    Parameters:
        dataframe (pd.DataFrame): The input dataset.
        categorical_feature (str): The name of the column representing the grouping variable (categorical).
        num_feature (str): The name of the column containing the numeric values to compare.
        center (str): Either 'mean' or 'median' — specifies the center of the distribution for the test.

    Returns:
        None - Prints the test statistic and conclusion.
    """
    print(f"🔍 Levene’s test: {num_feature} ~ {categorical_feature}")
    # Extract unique group labels
    groups = dataframe[categorical_feature].unique()    
    # Create a list of values for each group
    data_groups = [dataframe[dataframe[categorical_feature] == g][num_feature] for g in groups]    
    # Perform Levene’s test
    stat, p = levene(*data_groups, center=center)
    
    print(f"Levene statistic: {stat:.3f}")
    print(f"p-value: {p}")
    if p > 0.05:
        print("🟢 Variances are approximately equal across groups.")
    else:
        print("⚪ Variances are significantly different across groups.")

def cal_mannwhitneyu(dataframe, categorical_feature, num_feature, show_plot = False):
    """
    Performs Mann-Whitney U test (also known as Wilcoxon rank-sum test) to check for significant difference between two independent groups.
    https://library.virginia.edu/data/articles/the-wilcoxon-rank-sum-test
    Parameters:
        dataframe (pd.DataFrame): The input dataset.
        categorical_feature (str): The name of the column representing the grouping variable (categorical).
        num_feature (str): The name of the column containing the numeric values to compare.
        plot_result (bool): Show plot. Default is False.

    Returns:
        None - Prints the test statistic and conclusion.
    """

    # Extract unique groups
    groups = dataframe[categorical_feature].dropna().unique()
    
    if len(groups) != 2:
        print(f"❌ Error: Mann-Whitney U test requires exactly 2 groups, but found {len(groups)}.")
        return
    else:
        print(f"🔍 Mann-Whitney U test: {num_feature} ~ {categorical_feature}")
        # Extract values for each group
        group1 = dataframe[dataframe[categorical_feature] == groups[0]][num_feature].dropna()
        group2 = dataframe[dataframe[categorical_feature] == groups[1]][num_feature].dropna()

        # Perform Mann-Whitney U test
        stat, p = mannwhitneyu(group1, group2, alternative="two-sided")

        # Output results
        print(f"Mann-Whitney U statistic: {stat:.3f}")
        print(f"p-value: {p}")
        if p <= 0.05:
            print("🟢 There is a significant difference between the two groups.")
            print("Median of DistanceFromHome by Attrition (Yes):", group1.median())
            print("Median of DistanceFromHome by Attrition (No):", group2.median())

            print("Mean of DistanceFromHome by Attrition (Yes):", group1.mean())
            print("Mean of DistanceFromHome by Attrition (No):", group2.mean())
        else:
            print("⚪ There is no significant difference between the two groups.")

        # Show boxplot
        if show_plot:
            sns.boxplot(data=dataframe, x=categorical_feature, y=num_feature, palette="Set2")
            plt.title(f"Boxplot of {num_feature} by {categorical_feature}", fontsize=14, weight="bold")
            plt.tight_layout()
            plt.show()
        else:
            pass

def t_test_with_cohens_d(data, categorical_feature, num_feature, equal_var = False, show_plot = False):
    """
    Performs Independent T-Test between two groups and calculates Cohen's d. <br>
    https://www.scribbr.com/statistics/t-test/
    Parameters:
        data (pd.DataFrame): Input DataFrame.
        categorical_feature (str): Column name for grouping variable (categorical).
        num_feature (str): Column name for the numeric feature to compare.
        plot_result (bool): Show plot. Default is False.

    Returns:
        None - Prints T-test results and Cohen's d value.
    """

    # Extract unique groups
    groups = data[categorical_feature].dropna().unique()

    if len(groups) > 2:
        print(f"❌ Error: Independent T-Test requires 2 groups.")
        return
    else:
        print(f"🔍 Independent T-Test: {num_feature} ~ {categorical_feature}")
        # Extract values
        x1 = data[data[categorical_feature] == groups[0]][num_feature].dropna()
        x2 = data[data[categorical_feature] == groups[1]][num_feature].dropna()

        # T-test (independent)
        t_stat, p_value = ttest_ind(x1, x2, equal_var=equal_var)  # Welch’s t-test if variances may differ

        # Calculate Cohen’s d
        nx1, nx2 = len(x1), len(x2)
        pooled_std = np.sqrt(((nx1 - 1)*np.var(x1, ddof=1) + (nx2 - 1)*np.var(x2, ddof=1)) / (nx1 + nx2 - 2))
        cohens_d = (np.mean(x1) - np.mean(x2)) / pooled_std

        # Output
        print(f"\n🔍 T-Test between group'{groups[0]}' and group '{groups[1]}':")
        print(f"t-statistic: {t_stat:.3f}")
        print(f"p-value: {p_value:.6f}")

        if p_value < 0.05:
            print("\n✅ Significant difference found (p < 0.05)")
            print(f"\n📏 Cohen's d: {cohens_d:.3f}")            
            # Interpretation of Cohen's d
            if abs(cohens_d) < 0.2:
                size = "small"
            elif abs(cohens_d) < 0.5:
                size = "medium"
            else:
                size = "large"
            print(f"🧠 Effect size interpretation: {size} effect")
        else:
            print("\nℹ️ No significant difference found (p >= 0.05)")
        
        # Show boxplot
        if show_plot:
            sns.boxplot(data=data, x=categorical_feature, y=num_feature, palette="Set2")
            plt.title(f"Boxplot of {num_feature} by {categorical_feature}", fontsize=14, weight="bold")
            plt.tight_layout()
            plt.show()
        else:
            pass

def perform_anova_with_tukey(df, numeric_feature, categorical_feature, typ=2, plot=False):
    """
    Performs ANOVA and Tukey's HSD post-hoc test if needed. <br>
    https://www.scribbr.com/statistics/one-way-anova/
    Parameters:
        df (pd.DataFrame): Input DataFrame.
        numeric_feature (str): Name of the numerical response variable.
        categorical_feature (str): Name of the categorical variable (independent).
        typ (int): Type of sum of squares to use (1, 2, or 3). Default is 2.
        plot (bool): Show plot. Default is False.

    Returns:
        None - Prints ANOVA results and optionally Tukey's HSD results.
    """

    # Extract unique groups
    groups = df[categorical_feature].dropna().unique()
    
    if len(groups) < 3:
        print(f"❌ Error: ANOVA requires 3 or more groups.")
        return
    else:
        print(f"\n🔍 ANOVA Test: {numeric_feature} ~ {categorical_feature} (Type {typ})")

        # Fit OLS model
        model = ols(f"{numeric_feature} ~ C({categorical_feature})", data=df).fit()

        # Perform ANOVA
        anova_table = anova_lm(model, typ=typ)
        print("\n📊 ANOVA Table:")
        print(anova_table)

        # Extract p-value
        p_value = anova_table["PR(>F)"].iloc[0]

        if p_value < 0.05:
            print("\n✅ Significant difference found (p < 0.05)")
            print("➡️ Performing Tukey's HSD post-hoc test:")

            tukey = pairwise_tukeyhsd(df[numeric_feature], df[categorical_feature])
            print(tukey.summary())
        else:
            print("\nℹ️ No significant difference found (p >= 0.05)")

        if plot:
            sns.boxplot(data=df, x=categorical_feature, y=numeric_feature, palette="Set2")
            plt.title(f"Boxplot of {numeric_feature} by {categorical_feature}", fontsize=14, weight="bold")
            plt.tight_layout()
            plt.show()
        else:
            pass

def perform_kruskal_test(df, categorical_feature, numeric_feature, plot = False):
    """
    Performs Kruskal-Wallis H-test for independent samples. <br>
    https://www.geeksforgeeks.org/kruskal-wallis-test
    Parameters:
        df (pd.DataFrame): Dataset.
        categorical_feature (str): Categorical column name.
        numeric_feature (str): Numerical column name.
        plot (bool): Show plot. Default is False.

    Returns:
        None - Prints Kruskal-Wallis test results.
    """
    import scikit_posthocs as sp
    # Extract values
    groups = df[categorical_feature].dropna().unique()
    if len(groups) < 3:
        print(f"❌ Error: Kruskal-Wallis H-test requires 3 or more groups.")
        return
    else:
        print(f"\n🔍 Kruskal-Wallis Test: {numeric_feature} ~ {categorical_feature}")
        data_groups = [df[df[categorical_feature] == g][numeric_feature].dropna() for g in groups]

        # Perform kruskal
        stat, p = kruskal(*data_groups)

        print(f"Kruskal-Wallis H-statistic: {stat:.3f}")
        print(f"p-value: {p}")
        
        if p < 0.05:
            print("🟢 Significant difference found. Running Dunn's Post-Hoc Test...")
            dunn_result = sp.posthoc_dunn(df, val_col=numeric_feature, group_col=categorical_feature, p_adjust="bonferroni")
            print(dunn_result)
        else:
            print("\nℹ️ No significant difference found (p >= 0.05)")

        # Boxplot
        if plot:
            sns.boxplot(data=df, x=categorical_feature, y=numeric_feature, palette="Set2")
            plt.title(f"Boxplot of {numeric_feature} by {categorical_feature}", fontsize=14, weight="bold")
            plt.tight_layout()
            plt.show()
        else:
            pass

# %% [markdown]
# ## Attrition Distribution

# %%
attri_Distribution  = df_HR_Attrition["Attrition"].value_counts()
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(12, 4.5))
# ax[0]
ax[0].pie(
    attri_Distribution,
    labels = ["Working Employees","Attrition Employee"],
    colors = ["#de6a73", "#d64550"],
    autopct = "%1.2f%%",
    startangle = 150,
    explode = (0, 0.08),
    shadow= True
)
ax[0].set_title("Attrition Distribution", weight="bold", fontsize=14, pad=25)

# ax[1]
sns.countplot(data=df_HR_Attrition, x = "Attrition", palette=["#de6a73", "#d64550"], ax=ax[1])
ax[1].set_title("Count plot of Attrition Distribution", weight="bold", fontsize=14, pad=25)
for container in ax[1].containers:
    ax[1].bar_label(container, fmt="%d", label_type="edge", fontsize=10, weight="bold")
ax[1].set_ylabel("Number of Employees")

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights into Attrition Distribution
#
# **Frequency of attrition category**
#
# - The count plot reveal the absolute counts of each type in the dataset:
# - `0` (Working employee) is the most category with 1233 occurrences, accounting for approximately `83.88%` of the dataset.
# - `1` (Attrition employee) is lower then group working employee with 237 occurrences, accounting for approximately `16.12%` of the dataset.
#
# ***Nearly 1 in 6 employees left — which is not negligible and deserves further investigation. In addition, the data is imbalanced, which will affect the prediction (the model will predict in favor of group 0)***

# %% [markdown]
# ## Numerical Feature Distributions

# %%
def plot_numerical_features(df=df_HR_Attrition, numerical_features = num_feature):
    fig, axes = plt.subplots(len(numerical_features), 2, figsize=(12, len(numerical_features)*4))
    axes = np.atleast_2d(axes)

    for i, feature in enumerate(numerical_features):
        sns.histplot(data=df[feature], palette="Blues", bins = 20, kde=True, ax=axes[i, 0])
        axes[i, 0].set_title(f"Histogram of {feature}")
        axes[i, 0].set_ylabel("")
        # axes[i, 0].set_facecolor("lightgray")
        # axes[i, 0].grid(color="gray", linestyle=":", linewidth=0.7)

        sns.boxplot(data=df[feature], palette="Blues", orient="h", ax=axes[i, 1])
        axes[i, 1].set_title(f"Horizontal Boxplot of {feature}")
        axes[i, 1].set_xlabel(feature)
        # axes[i, 1].set_facecolor("lightgray")
        # axes[i, 1].grid(color="gray", linestyle=":", linewidth=0.7)

    plt.tight_layout()
    plt.show()
plot_numerical_features()

# %%
def check_skewness(data = df_HR_Attrition, numerical_features = num_feature, highlight=True, sort=True):
    skewness_dict = {}
    for feature in numerical_features:
        skew = data[feature].skew(skipna=True)
        skewness_dict[feature] = skew

    skew_df = pd.DataFrame.from_dict(skewness_dict, orient='index', columns=['Skewness'])
    if sort:
        skew_df = skew_df.reindex(skew_df['Skewness'].abs().sort_values(ascending=False).index)
    
    print(f"\n🔍 Skewness for dataset:")
    print("-"*65)
    print(f"{'Feature':<23} | {'Skewness':<10} | {'Remark'}")
    print("-"*65)
    for feature, row in skew_df.iterrows():
        skew = row['Skewness']
        abs_skew = abs(skew)
        if abs_skew > 1:
            remark = "Highly skewed"
            color = "\033[91m"  
        elif abs_skew > 0.5:
            remark = "Moderately skewed"
            color = "\033[93m"  
        else:
            remark = "Approximately symmetric"
            color = ''
        endc = '\033[0m' if color else ''
        if highlight and color:
            print(f"{color}{feature:<23} | {skew:>+9.4f} | {remark}{endc}")
        else:
            print(f"{feature:<23} | {skew:>+9.4f} | {remark}")
    print("-"*65)
    return skew_df

skew_data = check_skewness()
# Out:
# 🔍 Skewness for dataset:
# -----------------------------------------------------------------
# Feature                 | Skewness   | Remark
# -----------------------------------------------------------------
# YearsSinceLastPromotion |   +1.9843 | Highly skewed
# YearsAtCompany          |   +1.7645 | Highly skewed
# MonthlyIncome           |   +1.3698 | Highly skewed
# TotalWorkingYears       |   +1.1172 | Highly skewed
# NumCompaniesWorked      |   +1.0265 | Highly skewed
# DistanceFromHome        |   +0.9581 | Moderately skewed
# YearsInCurrentRole      |   +0.9174 | Moderately skewed
# YearsWithCurrManager    |   +0.8335 | Moderately skewed
# PercentSalaryHike       |   +0.8211 | Moderately skewed
# TrainingTimesLastYear   |   +0.5531 | Moderately skewed
# Age                     |   +0.4133 | Approximately symmetric
# HourlyRate              |   -0.0323 | Approximately symmetric
# MonthlyRate             |   +0.0186 | Approximately symmetric
# ...

# %% [markdown]
# #### Insights on Numerical Feature Distributions
#
# **Shape and Spread of Distributions**
#
# - **Histograms** reveal that all features are distributed fairly evenly across their respective ranges.
# - **Boxplots** confirm that the central 50% of values (the interquartile range), and the whiskers (showing the range).
#
# **Skewness Analysis**
#
# - The **skewness values** for numerical features (Age, HourlyRate, MonthlyRate, DailyRate) in dataset are less than 0.5, indicating that the distributions are **approximately symmetric** which means:
#   - There is no need for transformations like log or Box-Cox to normalize these features.
#   - Most machine learning algorithms will be able to handle these features without bias due to skewed distributions.
#
# - The **skewness values** for numerical features (Age, HourlyRate, MonthlyRate, DailyRate) in dataset are less than 0.5, indicating that the distributions are **approximately symmetric**.
# - The features: `MonthlyIncome`, `DistanceFromHome`, `YearsAtCompany`, `TotalWorkingYears`, `NumCompaniesWorked`, `YearsSinceLastPromotion`, `PercentSalaryHike`, `TrainingTimesLastYear`, `YearsInCurrentRole` and `YearsWithCurrManager` have **skewness values** greater than 0.5, indicating that the distributions are **Highly/Moderately symmetric**. Many model assumes **normal distribution** but in reality data points may not be perfectly symmetric. If the data are skewed, then this kind of model will always underestimate the skewness risk.The more the data is skewed the less accurate the model will be. We need to handle skewness in chapter **Data Preprocessing**

# %% [markdown]
# ### Correlation Analysis of Numerical Features
#
# 1. **What is Correlation?**
#
# **Correlation** measures the **strength and direction of a linear relationship** between two variables.
#
# * The correlation coefficient (usually denoted as **r**) ranges from **-1 to 1**.
#
# ---
#
# 2. **Interpretation of Correlation Values**
#
# | Value of r | Relationship Type           | Interpretation                               |
# | ---------- | --------------------------- | -------------------------------------------- |
# | `r ≈ 1`    | Strong positive correlation | As X increases, Y also increases linearly    |
# | `r ≈ -1`   | Strong negative correlation | As X increases, Y decreases linearly         |
# | `r ≈ 0`    | No linear correlation       | No clear linear relationship between X and Y |
#
# **Common interpretation of |r|**
#
# ![](https://i.ibb.co/TQ3FbQK/correlation.png)
#
# ---
#
# 3. **Pearson Correlation Formula**
#
# $$
# r = \frac{\sum (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum (x_i - \bar{x})^2 \cdot \sum (y_i - \bar{y})^2}}
# $$
#
# * $x_i, y_i$: observed values
# * $\bar{x}, \bar{y}$: sample means of X and Y

# %%
corr_matrix = df_HR_Attrition.drop(columns="Attrition", axis=1).corr(numeric_only=True)
# one_like can build a matrix of boolean(True, False) with the same shape as our data
ones_corr = np.ones_like(corr_matrix, dtype=bool)
mask = np.triu(ones_corr)
adjusted_mask = mask[1:, :-1]
adjusted_cereal_corr = corr_matrix.iloc[1:, :-1]

fig, ax = plt.subplots(figsize = (10, 9))
# That method uses HUSL colors, so you need hue, saturation, and lightness. 
# I used hsluv.org to select the colors of this chart.
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

sns.heatmap(data=adjusted_cereal_corr, mask=adjusted_mask,
            annot=True, fmt=".2f", cmap=cmap,
            vmin=-1, vmax=1, linecolor="white", linewidths=0.5)

title = 'CORRELATION MATRIX COMPOSITION\n'
ax.set_title(title, loc='left', fontsize=18, weight="bold");

# %% [markdown]
# #### Insights from Correlation Analysis of Numerical Features
#
# **Overall Weak Correlations:** Most correlation coefficients are close to zero, indicating **little to no linear relationship** between pairs of features.
#
# **Feature Independence**: There are many pairs of features with good correlation coefficients ranging from **weak, moderate and strong** such as:
# - TotalWorkingYears ↔ Age (0.68): Have a linear relationship with each other.
# - TotalWorkingYears ↔ MonthlyIncome (0.77): Employees with more experience tend to earn higher salaries. While not surprising, this is solid evidence for use in performance reviews or salary negotiations.
# - Years at Company ↔ Years in Current Role (0.76): Employees who stay longer at the company often remain in the same role, possibly indicating either stability. <br>
# ....
#
# **Implications for Modeling**
#
# - The near-zero correlations imply that each numerical feature provides **unique, non-redundant information**.
# - This independence is beneficial because it reduces **multicollinearity** issues in models, allowing algorithms to learn the distinct impact of each feature without confounding effects.
# - However, the lack of strong linear relationships suggests that **complex or non-linear models** (e.g., tree-based methods, neural networks) might better capture interactions or subtle patterns that linear correlation does not reveal.

# %% [markdown]
# ## Categorical Feature Distributions

# %%
# Function to display barplot and pie chart for categorical columns
def plot_categorical_distribution(feature, df = df_HR_Attrition, order = None):
    fig, ax = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(12, 5))

    sns.countplot(data=df, y = feature, ax=ax[0], palette="husl", order=order)
    ax[0].set_title(f"Count plot of {feature}", fontsize=14, pad=20)
    ax[0].set_ylabel(feature)
    ax[0].set_xlabel("")
    # ax[0].grid(axis="x", color="gray", linestyle=":", linewidth=0.7)
    # sns.despine(ax=ax[0], top=True, right=True, left=False, bottom=False)

    for p in ax[0].patches:
        width = p.get_width()
        y = p.get_y() + p.get_height() / 2
        ax[0].text(width + max(df[feature].value_counts())*0.01, y,
                f"{int(width)}", 
                ha="left", va="center", fontsize=10, fontweight="bold", color="black")

    feature_counts = df[feature].value_counts().sort_index()
    wedges, texts, autotexts = ax[1].pie(
        feature_counts,
        labels=feature_counts.index,
        autopct="%1.1f%%",
        startangle=90,
        colors=sns.color_palette("husl", len(feature_counts)),
        wedgeprops=dict(width=0.4, edgecolor="w"),
        radius=1.2
    )

    for text in texts + autotexts:
        text.set_fontsize(10)
        text.set_fontweight("bold")

    centre_circle = plt.Circle((0, 0), 0.70, fc="white")
    ax[1].add_artist(centre_circle)
    ax[1].set_title(f"Percentage Distribution of {feature}", pad=25)
    ax[1].axis("equal")

    plt.tight_layout()
    plt.show()

# %%
plot_categorical_distribution(feature="BusinessTravel")

# %% [markdown]
# **BusinessTravel:**
# * 3 levels; mostly **Travel\_Rarely** (\~71%) ⇒ the majority of employees **rarely travel** for work.
# * Only a small portion **Travel\_Frequently** or **Non-Travel**.

# %%
plot_categorical_distribution(feature="Department")

# %% [markdown]
# **Department**
#
# * **Research & Development** dominates (\~65.4%).
# * **Sales** and **Human Resources** have fewer employees ⇒ the organization is more technical-focused than sales and human resources.

# %%
plot_categorical_distribution(feature="Education")

# %% [markdown]
# * 5 levels, most common is **Bachelor** and **Master** (\~66%) ⇒ most employees have a **college and master degree**.
# * Higher education levels like Master and Doctorate are less common.

# %%
plot_categorical_distribution(feature="EducationField")

# %% [markdown]
# * 6 distinct fields, **Life Sciences** and **Medical** is the most prevalent (\~73%) → aligns with the R\&D focus.
# * Other fields like **Marketing** and **Human Resources** have fewer employees.

# %%
plot_categorical_distribution(feature="EnvironmentSatisfaction", order=["Low", "Medium", "High", "Very High"])

# %% [markdown]
# * **High** is the most frequent level → employees are generally **satisfied with their work environment**.
# * However, some dissatisfaction still exists and may require attention.

# %%
plot_categorical_distribution(feature="Gender")

# %% [markdown]
# * **Male** dominates (\~60%) → there may be a **gender imbalance** in the workforce.

# %%
plot_categorical_distribution(feature="JobInvolvement", order=["Low", "Medium", "High", "Very High"])

# %% [markdown]
# * **High** is most common → a positive sign of a strong workplace culture or environment.
# * **Medium** is accounting for 25.5% (375 people), this group holds potential.
# * **Low** (5.6% / 83 people) may suggest dissatisfaction or a lack of direction at work.
# * **Very High** (9.8% / 144 people) sounds great but could carry risks of burnout if not managed well.

# %%
plot_categorical_distribution(feature="JobLevel")

# %% [markdown]
# * Mostly at **Level 1 and 2** (\~73%) ⇒ the workforce is primarily **entry to mid-level**.
# * Typical in most organizations, where fewer people occupy senior, strategic roles.

# %%
plot_categorical_distribution(feature="JobRole")

# %% [markdown]
# * **Sales Executive** is the top job role, followed by **Research Scientist**.
# * Roles are fairly distributed, showing **organizational diversity** in functions.

# %%
plot_categorical_distribution(feature="JobSatisfaction", order=["Low", "Medium", "High", "Very High"])

# %% [markdown]
# * **Very High** is the most reported level ⇒ employees are generally **happy with their jobs**.
# * However, some dissatisfaction exists and should not be overlooked.

# %%
plot_categorical_distribution(feature="MaritalStatus")

# %% [markdown]
# * Most are **Married** (\~46%) ⇒ could have implications on **retention** and **work-life expectations**.

# %%
plot_categorical_distribution(feature="OverTime")

# %% [markdown]
# * Majority marked **No** (\~72%) ⇒ most employees **do not work overtime**, or overtime is well-managed.

# %%
plot_categorical_distribution(feature="PerformanceRating")

# %% [markdown]
# * The majority of employees are rated Excellent, which may reflect that the company has fairly high performance standards but is not too strict.
# * Employees rated Outstanding account for a small percentage, and may be individuals who excel in their work.

# %%
plot_categorical_distribution(feature="RelationshipSatisfaction", order=["Low", "Medium", "High", "Very High"])

# %% [markdown]
# * Most report **High and Very High** ⇒ suggests **positive interpersonal relationships** at the workplace.
# * A small portion of employees rate their satisfaction as Medium or Low, which may be related to issues such as conflict at work, lack of support from colleagues or management.

# %%
plot_categorical_distribution(feature="StockOptionLevel", order=["Basic", "Standard", "Advanced", "Elite"])

# %% [markdown]
# * The majority of employees are in the Basic and Standard tiers, which may reflect that the company does not focus on offering stock options as a common reward.
# * The small percentage of employees in the Advanced and Elite tiers may be employees in senior positions or with outstanding performance.

# %%
plot_categorical_distribution(feature="WorkLifeBalance",
                              order=["Bad", "Good", "Better", "Best"])

# %% [markdown]
# * **Better** is the dominant category ⇒ employees generally feel they have a **healthy work-life balance**.
# * Very few rated it "Bad" ⇒ this is a **strength** for the company.

# %% [markdown]
# ### Insights on Categorical Feature Distributions
#
# - The distribution `BusinessTravel` suggests that the business travel is not a common aspect of the job.
# - The distribution `Department` indicates that the company is heavily **R\&D-oriented**.
# - With the majority of employees having **Bachelor** and **Master** educational qualifications in the distribution `Education`, it can be shown that the company likely has high educational requirements in hiring. Furthermore, the company is R&D oriented so it is understandable that the company requires high educational qualifications in hiring.
# - From the distribution `EducationField` indicates that the company operates in sectors such as healthcare, biotech, or life sciences and technical knowledge in biological and medical fields is highly required. Of course it suits an R&D oriented company.
# - Nearly `40%` of employees fall into Medium or Low satisfaction categories in the distribution `EnvironmentSatisfaction`. May correlate with employee attrition or lower productivity—worth investigating further.
# - The company focuses on R&D so it is more suitable for men than women, so it is understandable that the number of male employees is higher than female employees.
# - The distribution `JobInvolvement` reveals a generally positive trend in employee job involvement, but also highlights pockets of concern that could impact performance or retention. It's an opportunity for leadership to tailor strategies according to each level of engagement.
# - The distribution `JobLevel` suggests a hierarchical structure with concentrated decision-making at the top.
# - The concentration in Sales Executive and Research Scientist suggests a strategic focus on product development and commercialization in the distribution `JobRole`.
# - With Low (19.7%) and Medium (19.0%) total nearly 40% in the distribution `JobSatisfaction` - are groups that may be facing challenges at work, lack motivation or do not see a clear development path.
# - With (~46%) in the distribution `MaritalStatus`, the Married group showed more stability in employment and were more likely to be interested in family-related benefits (e.g., insurance, childcare assistance).
# - The distribution `OverTime` shows that the majority of employees do not work overtime, but there is still a significant proportion (28.3%) who do. This may impact employee satisfaction and attrition rates. The company should focus on improving work policies to reduce the burden on employees who work overtime and to maintain a healthy work-life balance.
# - The distribution `PerformanceRating` shows that the majority of employees were rated Excellent, while only a small portion were rated Outstanding. This may reflect the company’s performance standards. The company should focus on attracting and retaining excellent employees, and motivating employees to achieve higher levels of performance.
# - The distribution `RelationshipSatisfaction` shows that the majority of employees are satisfied with their work relationships (High and Very High accounts for 60.6%). However, there is still a portion of employees (39.4%) who are dissatisfied or only moderately satisfied. Companies should focus on improving the satisfaction level of this group of employees to reduce turnover and increase engagement at work.
# - The distribution `StockOptionLevel` shows that the majority of employees are in the Basic and Standard stock option tiers, while only a small portion are in the Advanced and Elite tiers. This may affect employee motivation and turnover.
# - The distribution `WorkLifeBalance` shows that the majority of employees rate their work-life balance as Better (60.7%), while the smallest group is Bad (5.4%). Companies should focus on improving the balance for the dissatisfied group of employees to reduce turnover and increase engagement at work.

# %% [markdown]
# ## Bivariate Analysis

# %%
# defining function for plotting
def bivariate_percent_plot(cat, df, figsize=(15, 6), order = None, rot = 0):
    fig, ax = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=figsize)
    # Plot 1
    # Calculate the total number of each "cat" by Attrition
    grouped = df.groupby([cat, "Attrition"]).size().unstack(fill_value=0)
    # Calculate the percentages
    percentages = grouped.div(grouped.sum(axis=1), axis=0) * 100
    if order is not None:
        percentages = percentages.loc[order]
        labels = order
    else:
        labels = percentages.index

    # That method uses HUSL colors, so you need hue, saturation, and lightness. 
    # I used hsluv.org to select the colors of this chart.
    cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
    # Draw stacked bar plot
    ax[0] = percentages.plot(kind="bar", stacked=True, cmap=cmap, ax = ax[0], use_index=True)
    for container in ax[0].containers:
        ax[0].bar_label(container, fmt='%1.2f%%', label_type="center", weight="bold", fontsize=10)
    if cat == "JobRole":
        rot = 45
    else:
        rot = 0
    ax[0].set_title(f"Percentage of Attrition by {cat}", fontsize=14, weight="bold")
    ax[0].set_xlabel(f"{cat}")
    ax[0].set_ylabel("% Attrition Rate")
    ax[0].set_xticklabels(labels = labels, rotation = rot)
    ax[0].legend(title="Attrition", bbox_to_anchor=(1.05, 1), loc="upper left")

    # Plot 2
    sns.countplot(data=df, hue = "Attrition", x = cat, palette="husl", ax=ax[1], order=order)
    # Show value for each bar.
    for container in ax[1].containers:
        ax[1].bar_label(container, fmt='%d', label_type="edge", fontsize=10, weight="bold")
    if cat == "JobRole":
        ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45)
    else:
        pass
    ax[1].set_title(f"Attrition by {cat}", fontsize=14, weight="bold")
    ax[1].set_xlabel(f"{cat}", fontsize=12)
    ax[1].set_ylabel("Number of Employees")
    ax[1].legend(title="Attrition", bbox_to_anchor=(1.05, 1), loc="upper left")
    plt.tight_layout()
    plt.show()

    cal_ChiSquare(cat_feature=cat, target_feature="Attrition", df=df)

# %%
# Function to create scatter plot for bivariate analysis 
def plot_scatter_and_histogram(feature, df = df_HR_Attrition, order = None):
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))

    sns.boxplot(y=feature, x="Attrition", data=df, hue="Attrition", palette="husl", ax=ax[0])
    ax[0].set_title(f"Box plot of Attrition distribution by {feature}", pad=15)
    ax[0].set_ylabel(f"{feature}", labelpad=10)
    # ax[0].grid(axis="y", color="gray", linestyle=":", alpha=0.7)

    sns.histplot(data=df, x=feature, hue="Attrition", 
                 bins=20, palette="husl", ax=ax[1], kde=True)
    ax[1].set_title(f"Histogram of Attrition distribution by {feature}", pad=15)
    ax[1].set_xlabel(f"{feature}", labelpad=10)
    ax[1].set_ylabel("Frequency", labelpad=10)
    # ax[1].grid(axis="y", color="gray", linestyle=":", alpha=0.7)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Attrition distribution by Gender

# %%
bivariate_percent_plot(cat="Gender", df= df_HR_Attrition)
# Exploring the attrition rate based on Gender
cm = sns.light_palette("blue", as_cmap=True)
(round(pd.crosstab(df_HR_Attrition["Gender"], df_HR_Attrition["Attrition"], normalize='columns') * 100, 2)).style.background_gradient(cmap = cm)
# Out:
# 🔍 Chi-Square Test of Independence: 'Gender' vs. 'Attrition'
# Chi-squared statistic: 1.117
# Degrees of freedom: 1
# p-value: 0.290572
# ⚪ No significant relationship found (fail to reject H₀).
# <style type="text/css">
# #T_dc4a2_row0_col0, #T_dc4a2_row0_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_dc4a2_row1_col0, #T_dc4a2_row1_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dc4a2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_dc4a2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_dc4a2_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc4a2_level0_row0" class="row_heading level0 row0" >Female</th>
# ...

# %% [markdown]
# 🔴 The difference in attrition between male and female is `2.21%`, which shows that male quit their jobs more than female <br>
# 🔴 The attrition does not depend on Gender according to result of Chi-Square Test of Independence.

# %% [markdown]
# ### Attrition distribution by Age

# %%
plot_scatter_and_histogram(feature="Age")
cal_shapiro(cat_feature="Attrition", num_feature="Age", df=df_HR_Attrition)
cal_mannwhitneyu(dataframe=df_HR_Attrition, categorical_feature="Attrition", num_feature="Age")
# Out:
# 🔎 Shapiro-Wilk Normality Test for Age across Attrition groups
# ********************************************************************************
#   Shapiro-Wilk statistic: 0.946
#   p-value: 0.000000
#   ⚪ Group 1 does not appear to follow a normal distribution.
#
# ********************************************************************************
#   Shapiro-Wilk statistic: 0.978
#   p-value: 0.000000
#   ⚪ Group 0 does not appear to follow a normal distribution.
#
# 🔍 Mann-Whitney U test: Age ~ Attrition
# Mann-Whitney U statistic: 106859.000
# p-value: 5.304342075341702e-11
# 🟢 There is a significant difference between the two groups.
# 📘 Interpretation: Small effect

# %% [markdown]
# ***From the chart above and result of Mann-Whitney U test, we can conclude that the attrition employees are younger than those who are still working at the company. The company's workforce is aging, which can cause many risks at work, such as the quality of the products produced is not up to standard, the sensitivity at work is also reduced due to age, health issues, etc.***

# %% [markdown]
# ### Attrition Distribution by BusinessTravel

# %%
bivariate_percent_plot(cat="BusinessTravel", df= df_HR_Attrition)
# Exploring the attrition rate based on BusinessTravel
cm = sns.light_palette("blue", as_cmap=True)
(round(pd.crosstab(df_HR_Attrition["BusinessTravel"], df_HR_Attrition["Attrition"], normalize='columns') * 100, 2)).style.background_gradient(cmap = cm)
# Out:
# 🔍 Chi-Square Test of Independence: 'BusinessTravel' vs. 'Attrition'
# Chi-squared statistic: 24.182
# Degrees of freedom: 2
# p-value: 0.000006
# 🟢 Significant relationship found between variables (reject H₀).
# <style type="text/css">
# #T_f2642_row0_col0, #T_f2642_row0_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_f2642_row1_col0 {
#   background-color: #dbdbf4;
#   color: #000000;
# }
# #T_f2642_row1_col1 {
#   background-color: #9191f8;
#   color: #f1f1f1;
# }
# #T_f2642_row2_col0, #T_f2642_row2_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2642">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_f2642_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f2642_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >BusinessTravel</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# ***The analysis shows that there is a significant relationship between BusinessTravel and Attrition. Employees who travel frequently (Travel_Frequently) have the highest turnover rate, while employees who do not travel (Non-Travel) have the lowest turnover rate. Companies should focus on improving support policies for employees who travel frequently to reduce turnover and increase job satisfaction.***

# %% [markdown]
# ### Attrition Distribution by DailyRate

# %%
plot_scatter_and_histogram(feature="DailyRate")
cal_shapiro(cat_feature="Attrition", num_feature="DailyRate", df=df_HR_Attrition)
cal_mannwhitneyu(dataframe=df_HR_Attrition, categorical_feature="Attrition", num_feature="DailyRate")
# Out:
# 🔎 Shapiro-Wilk Normality Test for DailyRate across Attrition groups
# ********************************************************************************
#   Shapiro-Wilk statistic: 0.950
#   p-value: 0.000000
#   ⚪ Group 1 does not appear to follow a normal distribution.
#
# ********************************************************************************
#   Shapiro-Wilk statistic: 0.954
#   p-value: 0.000000
#   ⚪ Group 0 does not appear to follow a normal distribution.
#
# 🔍 Mann-Whitney U test: DailyRate ~ Attrition
# Mann-Whitney U statistic: 133042.000
# p-value: 0.029004575546528265
# 🟢 There is a significant difference between the two groups.
# 📘 Interpretation: Very small/negligible effect

# %% [markdown]
# ***The analysis showed that DailyRate did not differ significantly between the two Attrition groups. Although the difference was statistically very small, the practical effect was insignificant. Companies should focus on other factors to reduce turnover and improve employee satisfaction.***

# %% [markdown]
# ### Attrition Distribution by Department

# %%
bivariate_percent_plot(cat="Department", df= df_HR_Attrition)
# Exploring the attrition rate based on Department
cm = sns.light_palette("blue", as_cmap=True)
(round(pd.crosstab(df_HR_Attrition["Department"], df_HR_Attrition["Attrition"], normalize='columns') * 100, 2)).style.background_gradient(cmap = cm)
# Out:
# 🔍 Chi-Square Test of Independence: 'Department' vs. 'Attrition'
# Chi-squared statistic: 10.796
# Degrees of freedom: 2
# p-value: 0.004526
# 🟢 Significant relationship found between variables (reject H₀).
# <style type="text/css">
# #T_cc56e_row0_col0, #T_cc56e_row0_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_cc56e_row1_col0, #T_cc56e_row1_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_cc56e_row2_col0 {
#   background-color: #9393f8;
#   color: #f1f1f1;
# }
# #T_cc56e_row2_col1 {
#   background-color: #5151fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cc56e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_cc56e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cc56e_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# ***The analysis shows that there is a significant relationship between Department and Attrition. The Sales department has the highest turnover rate (20.63%), while the Research & Development department has the lowest turnover rate (13.84%). The company should focus on improving the work environment and support for the Sales department to reduce turnover and increase employee satisfaction.***

# %% [markdown]
# ### Attrition Distribution by DistanceFromHome

# %%
plot_scatter_and_histogram(feature="DistanceFromHome")
cal_shapiro(cat_feature="Attrition", num_feature="DistanceFromHome", df=df_HR_Attrition)
cal_mannwhitneyu(dataframe=df_HR_Attrition, categorical_feature="Attrition", num_feature="DistanceFromHome")
# Out:
# 🔎 Shapiro-Wilk Normality Test for DistanceFromHome across Attrition groups
# ********************************************************************************
#   Shapiro-Wilk statistic: 0.896
#   p-value: 0.000000
#   ⚪ Group 1 does not appear to follow a normal distribution.
#
# ********************************************************************************
#   Shapiro-Wilk statistic: 0.853
#   p-value: 0.000000
#   ⚪ Group 0 does not appear to follow a normal distribution.
#
# 🔍 Mann-Whitney U test: DistanceFromHome ~ Attrition
# Mann-Whitney U statistic: 164225.500
# p-value: 0.0023870470273627984
# 🟢 There is a significant difference between the two groups.
# Median of DistanceFromHome by Attrition (Yes): 9.0
# Median of DistanceFromHome by Attrition (No): 7.0
# Mean of DistanceFromHome by Attrition (Yes): 10.632911392405063
# Mean of DistanceFromHome by Attrition (No): 8.915652879156529

# %% [markdown]
# ***There is a difference between the two groups, namely the group that quit their jobs has a larger distance from home to the company than the group that did not quit their jobs (the Median and Mean of the quit group are larger). This may affect the quitting of jobs.***
